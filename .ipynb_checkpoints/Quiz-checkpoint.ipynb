# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Sample-Superstore-Subset-Excel.xlsx")
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
#Q1 : 1. Find the total sales value for 2010 orders shipped with "Low" priority

# %%
#Q2 : 2. Which product has the highest total sales?

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
df.groupby("Sales")[["Product Name"]].describe().tail(3)
# Out:
#           Product Name         \
#                  count unique
# Sales
# 48418.58             1      1
# 50332.66             1      1
# 100119.16            1      1
#
#
#                                                          top freq
# Sales
# 48418.58                       Canon PC1080F Personal Copier    1
# 50332.66               Canon imageCLASS 2200 Advanced Copier    1
# 100119.16  Riverside Palais Royal Lawyers Bookcase, Royal...    1

# %%
# Out:
#                                                    Unit Price          \
#                                                         count    mean
# Product Name
# "While you Were Out" Message Book, One Form per...        6.0    3.71
# #10 Self-Seal White Envelopes                             5.0   11.09
# #10 White Business Envelopes,4 1/8 x 9 1/2               14.0   15.67
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                  18.0    8.74
# #10- 4 1/8" x 9 1/2" Security-Tint Envelopes              9.0    7.64
# ...                                                       ...     ...
# i500plus                                                  2.0   65.99
# i600                                                      3.0  125.99
# iDEN i550                                                 2.0  205.99
# iDEN i95                                                  4.0   65.99
# iDENi80s                                                  5.0   65.99
#
# ...

# %%
# Out:
#   File "<ipython-input-30-7fc1a05d72c1>", line 1
#     df.groupby("Unit Price").apply(lambda x: x."Product Name")
#                                                             ^
# SyntaxError: invalid syntax
